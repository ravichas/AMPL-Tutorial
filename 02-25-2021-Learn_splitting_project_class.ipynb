# %%
import pdb
import logging
import os
import sys
import deepchem as dc
import numpy as np
import pandas as pd
from deepchem.data import DiskDataset
import collections
import atomsci.ddm.pipeline.splitting as split
# Out:
# /usr/mic/bio/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# Example set of molecules to use as dataset to learn Splitting

mols = [
    'C1=CC2=C(C=C1)C1=CC=CC=C21', 'O=C1C=CC(=O)C2=C1OC=CO2', 'C1=C[N]C=C1',
    'C1=CC=CC=C[C+]1', 'C1=[C]NC=C1', 'N[C@@H](C)C(=O)O', 'N[C@H](C)C(=O)O',
    'CC', 'O=C=O', 'C#N', 'CCN(CC)CC', 'CC(=O)O', 'C1CCCCC1', 'c1ccccc1'
]
print("Original set of molecules")
print(mols)
# Out:
# Original set of molecules
# ['C1=CC2=C(C=C1)C1=CC=CC=C21', 'O=C1C=CC(=O)C2=C1OC=CO2', 'C1=C[N]C=C1', 'C1=CC=CC=C[C+]1', 'C1=[C]NC=C1', 'N[C@@H](C)C(=O)O', 'N[C@H](C)C(=O)O', 'CC', 'O=C=O', 'C#N', 'CCN(CC)CC', 'CC(=O)O', 'C1CCCCC1', 'c1ccccc1']

# %%
# Learn using the Random Splitter

dataset = dc.data.NumpyDataset(X=mols, ids=mols)
splitter = dc.splits.RandomSplitter()
train, valid, test = splitter.train_valid_test_split(dataset)
# The return values are dc.data.Dataset objects so we need to extract
# the ids
print("Training set")
print(train.ids)
print("Valid set")
print(valid.ids)
print("Test set")
print(test.ids)
# Out:
# Training set
# ['C1=[C]NC=C1' 'CCN(CC)CC' 'C1=C[N]C=C1' 'C1=CC2=C(C=C1)C1=CC=CC=C21'
#  'C#N' 'c1ccccc1' 'O=C=O' 'CC(=O)O' 'C1=CC=CC=C[C+]1' 'C1CCCCC1' 'CC']
# Valid set
# ['O=C1C=CC(=O)C2=C1OC=CO2']
# Test set
# ['N[C@H](C)C(=O)O' 'N[C@@H](C)C(=O)O']

# %%
# Learn using the Scaffold Splitter

dataset = dc.data.NumpyDataset(X=mols, ids=mols)
splitter = dc.splits.ScaffoldSplitter()
train, valid, test = splitter.train_valid_test_split(dataset)
# The return values are dc.data.Dataset objects so we need to extract
# the ids
print("Training set")
print(train.ids)
print("Valid set")
print(valid.ids)
print("Test set")
print(test.ids)
# Out:
# Training set
# ['N[C@@H](C)C(=O)O' 'N[C@H](C)C(=O)O' 'CC' 'O=C=O' 'C#N' 'CCN(CC)CC'
#  'CC(=O)O' 'c1ccccc1' 'C1CCCCC1' 'C1=[C]NC=C1' 'C1=CC=CC=C[C+]1']
# Valid set
# ['C1=C[N]C=C1']
# Test set
# ['O=C1C=CC(=O)C2=C1OC=CO2' 'C1=CC2=C(C=C1)C1=CC=CC=C21']

# %%
from atomsci.ddm.pipeline import model_pipeline as mp
from atomsci.ddm.pipeline import parameter_parser as parse
# Out:
# /usr/mic/bio/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Scaffold Split Example (DO NOT RUN DURING CLASS)
#dataset_split 
params = {
    "script_dir": "/usr/workspace/hiran/AMPL/atomsci/ddm",
    "python_path": "/usr/mic/bio/anaconda3/bin/python",
    "dataset_key" : "/usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all.csv",
    "datastore": "False",
    "split_only": "True",
    "splitter": "scaffold",
    "split_valid_frac": "0.15",
    "split_test_frac": "0.15",
    "previously_split": "False",
    "prediction_type": "regression",
    "response_cols" : "PIC50",
    "id_col": "compound_id",
    "smiles_col" : "base_rdkit_smiles",
    "result_dir": "/p/lustre3/hiran/atomcode/results_dir/kcnh2_models_project_class",
    "system": "LC",
    "transformers": "True",
    "model_type": "NN",
    "featurizer": "graphconv",
    "descriptor_type": "graphconv",
    "learning_rate": "0.0007",
    "layer_sizes": "64,64,32",
    "dropouts" : "0.0,0.0,0.0",
    "save_results": "False",
    "max_epochs": "100",
    "verbose": "True"
}
pparams = parse.wrapper(params)
MP = mp.ModelPipeline(pparams)
MP.train_model()
# Out:
# number of features: 75
# 2021-02-24 14:24:26,088 Splitting data by scaffold
# 2021-02-24 14:25:00,436 Dataset split table saved to /usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all_train_valid_test_scaffold_0cab25e3-954f-4cc1-9eba-deb365468ecd.csv

# %%
split_dataset = pd.read_csv("/usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all_train_valid_test_scaffold_0cab25e3-954f-4cc1-9eba-deb365468ecd.csv")

# %%
split_dataset.pivot_table(index=['subset'], aggfunc='size')
# Out:
# subset
# test      898
# train    4189
# valid     898
# dtype: int64

# %%
# Random Split Example (DO NOT RUN DURING CLASS) 
#dataset_split
params = {
    "script_dir": "/usr/workspace/hiran/AMPL/atomsci/ddm",
    "python_path": "/usr/mic/bio/anaconda3/bin/python",
    "dataset_key" : "/usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all.csv",
    "datastore": "False",
    "split_only": "True",
    "splitter": "random",
    "split_valid_frac": "0.15",
    "split_test_frac": "0.15",
    "previously_split": "False",
    "prediction_type": "regression",
    "response_cols" : "PIC50",
    "id_col": "compound_id",
    "smiles_col" : "base_rdkit_smiles",
    "result_dir": "/p/lustre3/hiran/atomcode/results_dir/kcnh2_models_project_class_randomsplit",
    "system": "LC",
    "transformers": "True",
    "model_type": "NN",
    "featurizer": "graphconv",
    "descriptor_type": "graphconv",
    "learning_rate": "0.0007",
    "layer_sizes": "64,64,32",
    "dropouts" : "0.0,0.0,0.0",
    "save_results": "False",
    "max_epochs": "100",
    "verbose": "True"
}
pparams = parse.wrapper(params)
MP = mp.ModelPipeline(pparams)
MP.train_model()
# Out:
# number of features: 75
# 2021-02-24 14:44:28,766 Splitting data by random
# 2021-02-24 14:44:39,683 Dataset split table saved to /usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all_train_valid_test_random_ede8e1bb-07a0-4306-92af-0262c7f03179.csv

# %%
split_dataset_randomsplit = pd.read_csv("/usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all_train_valid_test_random_ede8e1bb-07a0-4306-92af-0262c7f03179.csv")

# %%
split_dataset_randomsplit.pivot_table(index=['subset'], aggfunc='size')
# Out:
# subset
# test      898
# train    4189
# valid     898
# dtype: int64

# %%
#Dataset Split using Random Split
split_dataset_randomsplit
# Out:
#                           cmpd_id  fold subset
# 0     OPEHXHIHHLIHNF-LZHZRURDSA-N     0  train
# 1     PYPUGVATTLSFNC-FQEVSTJZSA-N     0  train
# 2     YGKGINZAHYHTNB-JLHYYAGUSA-N     0  train
# 3     WRUVHZFRRXADMC-UHFFFAOYSA-N     0  train
# 4     MFWNKCLOYSRHCJ-UHFFFAOYSA-N     0  train
# 5     KENVEDVQQZAGDU-UHFFFAOYSA-N     0  train
# 6     WIDBHTRKXQCNBH-UHFFFAOYSA-N     0  train
# 7     MELLPTHIQUBYAE-LJAQVGFWSA-N     0  train
# 8     PBDMWGSHTOZGOM-HNNXBMFYSA-N     0  train
# 9     TXYRXUAVFCQDBX-UHFFFAOYSA-N     0  train
# 10    VYFZIPUVTIMYCJ-NWDGAFQWSA-N     0  train
# 11    ZWGZFELFBFJIHY-CQSZACIVSA-N     0  train
# 12    GPWMNUXSJDSCAV-NZICPMOKSA-N     0  train
# 13    TYYPWLNLMMRCKN-UHFFFAOYSA-N     0  train
# 14    PISDDJAHCRTSLZ-WIIYFNMSSA-N     0  train
# 15    QOYHHIBFXOOADH-UHFFFAOYSA-N     0  train
# 16    LJDOMRHCUJTSAI-ZBBHSQCGSA-N     0  train
# 17    MQVCFNZOSWGNGF-FNORWQNLSA-N     0  train
# 18    VLPIATFUUWWMKC-UHFFFAOYSA-N     0  train
# 19    RPJKTTWXGDPQJT-UHFFFAOYSA-N     0  train
# 20    YVVMAGRTTSOPEO-UHFFFAOYSA-N     0  train
# 21    VBVWWMHZQQUOKJ-CQSZACIVSA-N     0  train
# 22    LADNPCFYVROVIW-UHFFFAOYSA-N     0  train
# 23    UALHUWYCEAVLAG-UHFFFAOYSA-N     0  train
# 24    MXFHZPNMOBHODH-UHFFFAOYSA-N     0  train
# 25    DZHNUHFOOBQJNH-UHFFFAOYSA-N     0  train
# 26    ALIKLTHFBZBJOJ-UHFFFAOYSA-N     0  train
# 27    UMQZMTNEQMDJIG-NOZRDPDXSA-N     0  train
# 28    YPQYVVMLRSSTFW-OAHLLOKOSA-N     0  train
# 29    REXDQAIKTDDWAC-GOSISDBHSA-N     0  train
# ...                           ...   ...    ...
# 5955  VSLZNKFMVLGHTG-VGXUOWJOSA-N     0   test
# 5956  OMMTWAGHTAHDIF-ROUUACIJSA-N     0   test
# 5957  WVTAOBVWAHTAMN-UHFFFAOYSA-N     0   test
# 5958  SJKMQTMFLAKEIX-NQCNTLBGSA-N     0   test
# 5959  RGIPZCBZGRZGDB-UHFFFAOYSA-N     0   test
# 5960  IAMSGDHGEMFJQC-INIZCTEOSA-N     0   test
# 5961  DGQYAOWRSYHPCE-ZXPTYKNPSA-N     0   test
# 5962  ZOSQXAHBYHMVCA-GXFFZTMASA-N     0   test
# 5963  LALUMVWWVOZFGT-UHFFFAOYSA-N     0   test
# 5964  VVLODOPNAHKFPY-UHFFFAOYSA-N     0   test
# 5965  YTAGXFHCBLRULY-UHFFFAOYSA-N     0   test
# 5966  MNSGCVNHLLGCDG-UHFFFAOYSA-N     0   test
# 5967  XRNKKDKAXAGLDX-UHFFFAOYSA-N     0   test
# 5968  ZPLLBOLUKODNHA-UHFFFAOYSA-N     0   test
# 5969  WDDCSCYJPKDFON-UHFFFAOYSA-N     0   test
# 5970  SEOMUFTWAUVWQZ-DICHSLLOSA-N     0   test
# 5971  CQJXBNDZWCFOLX-UHFFFAOYSA-N     0   test
# 5972  OMMVFRZSBCRMQD-LJYZBVLISA-N     0   test
# 5973  MNWIDQPCFXVVRZ-UHFFFAOYSA-N     0   test
# 5974  NWXMOGAAGJJIMH-UHFFFAOYSA-N     0   test
# 5975  XMDRMFODQNHFJV-NQCNTLBGSA-N     0   test
# 5976  FEFGAECMIYQVFL-MUUNZHRXSA-N     0   test
# 5977  ONFHYZFLYSWGHO-BUHFOSPRSA-N     0   test
# 5978  SUZTVAUFNKMZOU-GOSISDBHSA-N     0   test
# 5979  OUVCUNKYIOXFPQ-VMPITWQZSA-N     0   test
# 5980  GZKLJWGUPQBVJQ-UHFFFAOYSA-N     0   test
# 5981  OITQGXHZUBWLHP-UHFFFAOYSA-N     0   test
# 5982  TYKANWVCVGBBPK-GFCCVEGCSA-N     0   test
# 5983  KVLFRAWTRWDEDF-IRXDYDNUSA-N     0   test
# 5984  MMBDWDAKDCKUAX-UHFFFAOYSA-N     0   test
#
# [5985 rows x 3 columns]

# %%
#Dataset Split using Scaffold Split
split_dataset
# Out:
#                           cmpd_id  fold subset
# 0     OPEHXHIHHLIHNF-LZHZRURDSA-N     0  train
# 1     PYPUGVATTLSFNC-FQEVSTJZSA-N     0  train
# 2     HXVMFBSINMZKRO-UHFFFAOYSA-N     0  train
# 3     WRUVHZFRRXADMC-UHFFFAOYSA-N     0  train
# 4     KENVEDVQQZAGDU-UHFFFAOYSA-N     0  train
# 5     TULDQRGKIWKKNV-SFHVURJKSA-N     0  train
# 6     WIDBHTRKXQCNBH-UHFFFAOYSA-N     0  train
# 7     MELLPTHIQUBYAE-LJAQVGFWSA-N     0  train
# 8     TXYRXUAVFCQDBX-UHFFFAOYSA-N     0  train
# 9     VYFZIPUVTIMYCJ-NWDGAFQWSA-N     0  train
# 10    WACGNBTYNJLDBB-FYWRMAATSA-N     0  train
# 11    NTBMDNFTKNXWSC-UHFFFAOYSA-N     0  train
# 12    TYYPWLNLMMRCKN-UHFFFAOYSA-N     0  train
# 13    PISDDJAHCRTSLZ-WIIYFNMSSA-N     0  train
# 14    MLHRKLZCJRKSHO-UHFFFAOYSA-N     0  train
# 15    MQVCFNZOSWGNGF-FNORWQNLSA-N     0  train
# 16    VLPIATFUUWWMKC-UHFFFAOYSA-N     0  train
# 17    LPHIWCBAJGQIIF-UHFFFAOYSA-N     0  train
# 18    RPJKTTWXGDPQJT-UHFFFAOYSA-N     0  train
# 19    LVFOPIOPFRVLSQ-HNNXBMFYSA-N     0  train
# 20    MEGFCBVTRXVKDO-KKSFZXQISA-N     0  train
# 21    LADNPCFYVROVIW-UHFFFAOYSA-N     0  train
# 22    PAIPDKUVYIEUKM-UHFFFAOYSA-N     0  train
# 23    UALHUWYCEAVLAG-UHFFFAOYSA-N     0  train
# 24    MXFHZPNMOBHODH-UHFFFAOYSA-N     0  train
# 25    QCJYFNUEZUCTJK-UHFFFAOYSA-N     0  train
# 26    ULFXUVFXHTYAIU-AZUAARDMSA-N     0  train
# 27    GFLQCBTXTRCREJ-UHFFFAOYSA-N     0  train
# 28    DZHNUHFOOBQJNH-UHFFFAOYSA-N     0  train
# 29    ALIKLTHFBZBJOJ-UHFFFAOYSA-N     0  train
# ...                           ...   ...    ...
# 5955  LTYILNNURKPDBG-VOTSOKGWSA-N     0   test
# 5956  HICPZJOPGHLRGA-NDEPHWFRSA-N     0   test
# 5957  XTKKCHSZIDZKRF-UHFFFAOYSA-N     0   test
# 5958  ZQMUEFCLRDQIPA-UHFFFAOYSA-N     0   test
# 5959  YOQCIOKHHDUPPQ-UHFFFAOYSA-N     0   test
# 5960  FLGHLGGIQDOQPD-XMMPIXPASA-N     0   test
# 5961  OWYPWYDPIBLTEG-QGZVFWFLSA-N     0   test
# 5962  LWAACTJZSQSIBS-UHFFFAOYSA-N     0   test
# 5963  HRQQSHKLURUDMQ-UHFFFAOYSA-N     0   test
# 5964  BWYGQPPOOUSMRI-CYBMUJFWSA-N     0   test
# 5965  NOMKZQKLENFAJZ-HOTGVXAUSA-N     0   test
# 5966  HVQAATXUCFUOMV-WCQYABFASA-N     0   test
# 5967  DBMAUWVASVSMOE-UHFFFAOYSA-N     0   test
# 5968  FJPDUNSHNPHJFS-UHFFFAOYSA-N     0   test
# 5969  MHQFMMJRYPCUAC-UQBPGWFLSA-N     0   test
# 5970  YCFCCUQNGIHNCB-QGZVFWFLSA-N     0   test
# 5971  IVAPPJUVOQYBHT-UHFFFAOYSA-N     0   test
# 5972  DIXSEWSBXAEKKY-OAHLLOKOSA-N     0   test
# 5973  PSQMUQFRXXYSAM-SMDDNHRTSA-N     0   test
# 5974  NIAOMAGQEARZHM-UHFFFAOYSA-N     0   test
# 5975  GBJOVRXLTKZGFS-UHFFFAOYSA-N     0   test
# 5976  ROPHIKMBWGQPQO-UHFFFAOYSA-M     0   test
# 5977  UIILMPGHICZFBB-LRDNONRASA-N     0   test
# 5978  RIJLVEAXPNLDTC-UHFFFAOYSA-N     0   test
# 5979  RFWVETIZUQEJEF-UHFFFAOYSA-N     0   test
# 5980  HLFQPMNDRXUKAD-UHFFFAOYSA-N     0   test
# 5981  JKTIXUXRNOXCFC-UHFFFAOYSA-N     0   test
# 5982  MMJRIJVMZMXHPL-UHFFFAOYSA-N     0   test
# 5983  HQFOXALTXMATRX-UHFFFAOYSA-N     0   test
# 5984  DGHURJYXAQLSSM-UHFFFAOYSA-N     0   test
#
# [5985 rows x 3 columns]

# %%
# Just checking to compare the split datasets
split_dataset.equals(split_dataset_randomsplit)
# Out:
# False

# %%
import atomsci.ddm.pipeline.model_pipeline as mp
import atomsci.ddm.pipeline.chem_diversity as cd
import atomsci.ddm.pipeline.parameter_parser as parse
import atomsci.ddm.pipeline.featurization as feat
import atomsci.ddm.pipeline.model_datasets as md
import atomsci.ddm.pipeline.model_wrapper as mod

import atomsci.ddm.pipeline.splitting as split
import atomsci.ddm.pipeline.perf_plots as pp
import atomsci.ddm.pipeline.model_tracker as trkr

from scipy.stats.kde import gaussian_kde
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)
matplotlib.rc('axes', labelsize=12)

# %matplotlib inline

# %%
# Performance table when using Scaffold Split
from atomsci.ddm.pipeline import compare_models as cmp
# Training dataset key
dataset_key = '/usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all.csv'

# Training dataset bucket
bucket = 'public'
collection = 'kcnh2_dtc'
collections = [collection]
collection_name = collection

training_perf_table = cmp.get_training_perf_table(dataset_key, bucket, collection_name)
# Out:
# Finding models trained on public dataset /usr/workspace/atom/public_dsets/DTC/ml_ready/kcnh2_dtc_base_smiles_all.csv
# Found 10 matching models

# %%
training_perf_table
# Out:
#    best_epoch                                        dataset_key  \
# 2          29  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 1          25  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 0          29  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 8          34  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 4          40  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 5          40  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 9          45  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 3          31  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 7          34  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
# 6          22  /usr/workspace/atom/public_dsets/DTC/ml_ready/...
#
#          dropouts featurizer  layer_sizes  learning_rate  max_epochs  \
# 2  0.00,0.00,0.00  graphconv  128,128,256         0.0007         100
# 1  0.00,0.00,0.00  graphconv   256,256,64         0.0007         100
# 0  0.00,0.00,0.00  graphconv  256,256,256         0.0007         100
# 8  0.00,0.00,0.00  graphconv    64,64,256         0.0007         100
# 4  0.00,0.00,0.00  graphconv  256,256,128         0.0007         100
# 5  0.00,0.00,0.00  graphconv   128,128,64         0.0007         100
# 9  0.00,0.00,0.00  graphconv    64,64,128         0.0007         100
# 3  0.00,0.00,0.00  graphconv  128,128,128         0.0007         100
# 7  0.00,0.00,0.00  graphconv     64,64,64         0.0007         100
# 6  0.00,0.00,0.00  graphconv     64,64,32         0.0007         100
#
#   model_type                            model_uuid  rf_estimators  \
# 2         NN  ee6407d8-6767-4931-9799-b1c22bf23a27            NaN
# 1         NN  9a82259c-0599-4e7f-acb6-269a4995c005            NaN
# 0         NN  a77a9b60-dc2e-447a-92bf-7d78118c4365            NaN
# 8         NN  a5054caf-476a-4cd1-a687-269f6cf9ddf1            NaN
# 4         NN  12e16a16-e329-4e1b-8855-f3443ac4a31f            NaN
# 5         NN  fa7d4728-26ff-46c9-9e0b-f4565683dc78            NaN
# 9         NN  3d9f96f6-b15d-4c01-b4fb-ba8c017c20d2            NaN
# 3         NN  0f0f3fac-72e1-4218-bcfc-67e5bf2a1780            NaN
# 7         NN  d7ba3898-7b87-4ed9-8720-b2c81ea120c0            NaN
# 6         NN  5ece022a-c70d-4494-b22c-997df414c380            NaN
#
#    rf_max_depth  rf_max_features  splitter  xgb_gamma  xgb_learning_rate  \
# 2           NaN              NaN  scaffold        NaN                NaN
# 1           NaN              NaN  scaffold        NaN                NaN
# 0           NaN              NaN  scaffold        NaN                NaN
# 8           NaN              NaN  scaffold        NaN                NaN
# 4           NaN              NaN  scaffold        NaN                NaN
# 5           NaN              NaN  scaffold        NaN                NaN
# 9           NaN              NaN  scaffold        NaN                NaN
# 3           NaN              NaN  scaffold        NaN                NaN
# 7           NaN              NaN  scaffold        NaN                NaN
# 6           NaN              NaN  scaffold        NaN                NaN
#
#    r2_score_train  r2_score_valid  r2_score_test
# 2        0.850257        0.457489       0.315570
# 1        0.803471        0.449899       0.320166
# 0        0.856982        0.447553       0.310497
# 8        0.821047        0.438644       0.316661
# 4        0.828562        0.426121       0.361736
# 5        0.797914        0.410568       0.325595
# 9        0.785872        0.403416       0.265150
# 3        0.816506        0.400714       0.341997
# 7        0.745418        0.384794       0.236780
# 6        0.710938        0.353172       0.268749
