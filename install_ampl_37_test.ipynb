# %% [markdown]
# <a href="https://colab.research.google.com/github/ravichas/AMPL-Tutorial/blob/master/install_ampl_37_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
! wget -c https://repo.anaconda.com/archive/Anaconda3-2019.10-Linux-x86_64.sh
! chmod +x Anaconda3-2019.10-Linux-x86_64.sh
! bash ./Anaconda3-2019.10-Linux-x86_64.sh -b -f -p /usr/local

# ! wget -c https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh 
# ! chmod +x Miniconda3-py37_4.9.2-Linux-x86_64.sh
# ! time bash Miniconda3-py37_4.9.2-Linux-x86_64.sh -b -f -p /usr/local

! time conda install -y -c deepchem -c rdkit -c conda-forge -c omnia deepchem-gpu=2.3.0
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
import deepchem as dc
# Out:
# --2021-03-09 18:10:30--  https://repo.anaconda.com/archive/Anaconda3-2019.10-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 530308481 (506M) [application/x-sh]
# Saving to: ‘Anaconda3-2019.10-Linux-x86_64.sh’
#
# Anaconda3-2019.10-L 100%[===================>] 505.74M   153MB/s    in 3.3s
#
# 2021-03-09 18:10:33 (153 MB/s) - ‘Anaconda3-2019.10-Linux-x86_64.sh’ saved [530308481/530308481]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py37_0
#     - anaconda-client==1.7.2=py37_0
#     - anaconda-navigator==1.9.7=py37_0
#     - anaconda-project==0.8.3=py_0
# ...

# %%
! time conda install -c conda-forge -y mordred bravado molvs
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - bravado
#     - molvs
#     - mordred
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bravado-11.0.3             |     pyhd8ed1ab_0          31 KB  conda-forge
#     bravado-core-5.17.0        |     pyh9f0ad1d_0          48 KB  conda-forge
#     jsonref-0.2                |             py_0          11 KB  conda-forge
#     molvs-0.1.1                |             py_0          25 KB  conda-forge
#     monotonic-1.5              |             py_0           9 KB  conda-forge
#     mordred-1.2.0              |             py_1         124 KB  conda-forge
#     simplejson-3.17.2          |   py37h8f50634_1         102 KB  conda-forge
#     swagger-spec-validator-2.7.3|     pyh9f0ad1d_0          21 KB  conda-forge
# ...

# %%
pwd
# Out:
# '/content'

# %%
# !wget https://raw.githubusercontent.com/ravichas/AMPL-Tutorial/master/config/install_AMPL_GPU_test.sh
# Out:
# --2021-03-09 18:21:14--  https://raw.githubusercontent.com/ravichas/AMPL-Tutorial/master/config/install_AMPL_GPU_test.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1100 (1.1K) [text/plain]
# Saving to: ‘install_AMPL_GPU_test.sh’
#
# install_AMPL_GPU_te 100%[===================>]   1.07K  --.-KB/s    in 0s
#
# 2021-03-09 18:21:14 (80.4 MB/s) - ‘install_AMPL_GPU_test.sh’ saved [1100/1100]

# %%
! chmod u+x install_AMPL_GPU_test.sh
! ./install_AMPL_GPU_test.sh
# Out:
# Cloning into 'AMPL'...
# remote: Enumerating objects: 240, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 1760 (delta 181), reused 142 (delta 115), pack-reused 1520
# Receiving objects: 100% (1760/1760), 9.61 MiB | 26.38 MiB/s, done.
# Resolving deltas: 100% (1002/1002), done.
# Branch 'pkg_upgrade' set up to track remote branch 'pkg_upgrade' from 'origin'.
# Switched to a new branch 'pkg_upgrade'
# patching file /content/github/AMPL/atomsci/ddm/pipeline/transformations.py
# patching file /content/github/AMPL/atomsci/ddm/__init__.py
# running build
# running build_py
# creating /content/github/AMPL.build/ampl/lib
# creating /content/github/AMPL.build/ampl/lib/atomsci
# copying atomsci/__init__.py -> /content/github/AMPL.build/ampl/lib/atomsci
# creating /content/github/AMPL.build/ampl/lib/atomsci/ddm
# copying atomsci/ddm/__init__.py -> /content/github/AMPL.build/ampl/lib/atomsci/ddm
# ...

# %%
# import sys
# sys.path.append('/content/AMPL/atomsci')
# if '/content/AMPL/lib/python3.7/site-packages' not in sys.path:
#     sys.path.insert(1, '/content/AMPL/lib/python3.7/site-packages')

# %%
# !wget https://raw.githubusercontent.com/ravichas/AMPL-Tutorial/master/datasets/Excape_HTR3A.tsv
# Out:
# --2021-03-09 18:21:28--  https://raw.githubusercontent.com/ravichas/AMPL-Tutorial/master/datasets/Excape_HTR3A.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 193150 (189K) [text/plain]
# Saving to: ‘Excape_HTR3A.tsv’
#
# Excape_HTR3A.tsv    100%[===================>] 188.62K  --.-KB/s    in 0.004s
#
# 2021-03-09 18:21:28 (41.7 MB/s) - ‘Excape_HTR3A.tsv’ saved [193150/193150]

# %%
import pandas as pd
# import atomsci.ddm.utils.data_curation_functions as dcf
import atomsci.ddm.utils.curate_data as curate_data
import atomsci.ddm.pipeline.diversity_plots as dp
import atomsci.ddm.pipeline.chem_diversity as cd
import atomsci.ddm.utils.struct_utils as struct_utils

# %%
excape = pd.read_csv("Excape_HTR3A.tsv", sep='\t')

# %%
excape['base_rdkit_smiles'] = excape.SMILES.apply(struct_utils.base_smiles_from_smiles)

# %%
excape
# Out:
#                   Ambit_InchiKey  ...                                             SMILES
# 0    AATPYXMXFBBKFO-KARVIEMNNA-N  ...          C=1C(=C(OC2=CN=C(N=C2N)N)C=C(C1OC)I)C(C)C
# 1    ABIDZKZAFOTHFB-CCUGXXBONA-N  ...  C1C2CCN(C1)C[C@H]2NC(C3=C4N=C(OC4=CC=C3)N5[C@H...
# 2    ABSDJNLAUZQHJY-UHFFFAOYNA-N  ...            N1(CCNCC1)C=2C(=CC=CC2)SC=3C=C(C=CC3)OC
# 3    ACKJXXOVSOCBPX-PHLAQJRANA-N  ...  O=C(NCCCCCCCNC=1C=2CCCCC2N=C3C1C=CC=C3)C4=C(C(...
# 4    ACKJXXOVSOCBPX-PHLAQJRANA-N  ...  C=1(N=C2C=CC=CC2=C(C1C)C(=O)NCCCCCCCNC=3C4=C(C...
# ..                           ...  ...                                                ...
# 644  ZTOYBNWVJQYBOX-KKBRQIQINA-N  ...  [C@@H]12N([C@@H](C[C@H](C1)NC(C3=C4C(OC(=N4)N5...
# 645  ZUFRPGFBOPXENO-UHFFFAOYNA-N  ...  N=1C(N(C(C2CC(CCC12)C)=O)N)=CCCCN3CCN(CC3)C=4N...
# 646  ZXDOWRQWHIUDFJ-ALLFDXPCNA-N  ...  O=C(NC1C[C@@H]2N([C@H](C1)CCC2)C)C3=C4OC(=NC4=...
# ...
